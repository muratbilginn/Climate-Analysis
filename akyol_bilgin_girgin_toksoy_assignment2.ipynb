# %%
import kagglehub


path = kagglehub.dataset_download("berkeleyearth/climate-change-earth-surface-temperature-data")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'climate-change-earth-surface-temperature-data' dataset.
# Path to dataset files: /kaggle/input/climate-change-earth-surface-temperature-data

# %%
import os

dosya_listesi = os.listdir(path)

csv_dosyalari = [f for f in dosya_listesi if f.endswith('.csv')]

print("CSV files:")
for dosya in csv_dosyalari:
    print(f"- {dosya}")
# Out:
# CSV files:
# - GlobalLandTemperaturesByCountry.csv
# - GlobalLandTemperaturesByState.csv
# - GlobalTemperatures.csv
# - GlobalLandTemperaturesByMajorCity.csv
# - GlobalLandTemperaturesByCity.csv

# %%
import pandas as pd
import os

csv_dosyalari = [f for f in os.listdir(path) if f.endswith('.csv')]

temiz_veriler = {}

print("Data Cleaning\n")

for dosya in csv_dosyalari:
    dosya_yolu = os.path.join(path, dosya)
    df = pd.read_csv(dosya_yolu)

    onceki_satir_sayisi = len(df)

    df_temiz = df.dropna().copy()

    sonraki_satir_sayisi = len(df_temiz)
    silinen_satir = onceki_satir_sayisi - sonraki_satir_sayisi

    temiz_veriler[dosya] = df_temiz

    print(f"File: {dosya}")
    print(f"  - Total Row: {onceki_satir_sayisi}")
    print(f"  - Deleted (NaN) Row: {silinen_satir}")
    print(f"  - Remaining Row: {sonraki_satir_sayisi}")
    print("-" * 30)
# Out:
# Data Cleaning
#
# File: GlobalLandTemperaturesByCountry.csv
#   - Total Row: 577462
#   - Deleted (NaN) Row: 32651
#   - Remaining Row: 544811
# ------------------------------
# File: GlobalLandTemperaturesByState.csv
#   - Total Row: 645675
#   - Deleted (NaN) Row: 25648
#   - Remaining Row: 620027
# ------------------------------
# File: GlobalTemperatures.csv
#   - Total Row: 3192
#   - Deleted (NaN) Row: 1200
#   - Remaining Row: 1992
# ------------------------------
# File: GlobalLandTemperaturesByMajorCity.csv
#   - Total Row: 239177
#   - Deleted (NaN) Row: 11002
#   - Remaining Row: 228175
# ------------------------------
# File: GlobalLandTemperaturesByCity.csv
#   - Total Row: 8599212
#   - Deleted (NaN) Row: 364130
#   - Remaining Row: 8235082
# ------------------------------

# %%
for dosya_adi, df_temiz in temiz_veriler.items():

    print(f"File: {dosya_adi} (The first 10 rows have been cleaned.)")


    display(df_temiz.head(10))
# Out:
# File: GlobalLandTemperaturesByCountry.csv (The first 10 rows have been cleaned.)
#             dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0   1743-11-01               4.384                          2.294   Åland
# 5   1744-04-01               1.530                          4.680   Åland
# 6   1744-05-01               6.702                          1.789   Åland
# 7   1744-06-01              11.609                          1.577   Åland
# 8   1744-07-01              15.342                          1.410   Åland
# 10  1744-09-01              11.702                          1.517   Åland
# 11  1744-10-01               5.477                          1.862   Åland
# 12  1744-11-01               3.407                          1.425   Åland
# 13  1744-12-01              -2.181                          1.641   Åland
# 14  1745-01-01              -3.850                          1.841   Åland
# File: GlobalLandTemperaturesByState.csv (The first 10 rows have been cleaned.)
# ...

# %%
import pandas as pd
import os

csv_dosyalari = [f for f in os.listdir(path) if f.endswith('.csv')]

for dosya in csv_dosyalari:
    print(f"\nFile Name: {dosya} ---")

    dosya_yolu = os.path.join(path, dosya)

    df = pd.read_csv(dosya_yolu)

    display(df.head(10))
# Out:
# File Name: GlobalLandTemperaturesByCountry.csv ---
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland
# 5  1744-04-01               1.530                          4.680   Åland
# 6  1744-05-01               6.702                          1.789   Åland
# 7  1744-06-01              11.609                          1.577   Åland
# 8  1744-07-01              15.342                          1.410   Åland
# 9  1744-08-01                 NaN                            NaN   Åland
# File Name: GlobalLandTemperaturesByState.csv ---
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df_global = temiz_veriler['GlobalTemperatures.csv'].copy()


df_global['dt'] = pd.to_datetime(df_global['dt'])
df_global['year'] = df_global['dt'].dt.year


yearly_temp = df_global.groupby('year')['LandAverageTemperature'].mean()


plt.figure(figsize=(14, 7))
sns.set_style("whitegrid")

plt.plot(yearly_temp.index, yearly_temp.values, label='Annual Average Temperature', color='tab:red', alpha=0.4)


plt.plot(yearly_temp.index, yearly_temp.rolling(window=10).mean(), label='10-Year Trendline', color='darkred', linewidth=2.5)


plt.title('Global Land Temperature Change (1750 - 2015)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Temperature (°C)', fontsize=12)
plt.legend()


plt.show()

# %%
import kagglehub

path = kagglehub.dataset_download("jarredpriester/global-sea-level-rise")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.39k/1.39k [00:00<00:00, 3.20MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/jarredpriester/global-sea-level-rise/versions/3

# %%
import kagglehub
import pandas as pd
import os

path = kagglehub.dataset_download("jarredpriester/global-sea-level-rise")

all_files = os.listdir(path)

csv_files = [f for f in all_files if f.endswith('.csv') and not f.startswith('.')]

csv_path = os.path.join(path, csv_files[0])
df = pd.read_csv(csv_path)
print(f"Başarıyla yüklendi: {csv_files[0]}")

df.head()
# Out:
# Using Colab cache for faster access to the 'global-sea-level-rise' dataset.
# Başarıyla yüklendi: Global_sea_level_rise.csv
#    year        date  mmfrom1993-2008average
# 0  1880  07/15/1880             -183.247396
# 1  1881  07/15/1881             -174.014062
# 2  1882  07/15/1882             -190.080729
# 3  1883  07/15/1883             -185.147396
# 4  1884  07/15/1884             -166.280729

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    143 non-null    int64
#  1   date                    143 non-null    object
#  2   mmfrom1993-2008average  143 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.5+ KB
#              year  mmfrom1993-2008average
# count   143.00000              143.000000
# mean   1951.00000              -79.729820
# std      41.42463               69.902279
# min    1880.00000             -190.080729
# 25%    1915.50000             -138.397396
# 50%    1951.00000              -87.447396
# 75%    1986.50000              -25.564062
# max    2022.00000               69.660000

# %%
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

path = kagglehub.dataset_download("jarredpriester/global-sea-level-rise")
csv_path = os.path.join(path, 'Global_sea_level_rise.csv')
df = pd.read_csv(csv_path)

df['date'] = pd.to_datetime(df['date'])

## Görselleştirme
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))


sns.lineplot(data=df, x='date', y='mmfrom1993-2008average', color='#2c7bb6', linewidth=2)

plt.title('Küresel Deniz Seviyesi Değişimi (1880 - Günümüz)', fontsize=14, pad=15)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Ortalama Seviye Değişimi (mm)', fontsize=12)


plt.tight_layout()
plt.show()
# Out:
# Using Colab cache for faster access to the 'global-sea-level-rise' dataset.

# %%
import kagglehub

path = kagglehub.dataset_download("mathurinache/list-of-countries-by-average-elevation")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.66k/1.66k [00:00<00:00, 1.82MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mathurinache/list-of-countries-by-average-elevation/versions/1

# %%
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

path = kagglehub.dataset_download("mathurinache/list-of-countries-by-average-elevation")
csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]
df = pd.read_csv(os.path.join(path, csv_file))


df.columns = df.columns.str.strip()
country_col = df.columns[0]
elevation_col = [c for c in df.columns if 'elevation' in c.lower()][0]


def clean_elevation(val):
    if pd.isna(val): return 0
    match = re.search(r'([-+]?[0-9,.]+)', str(val))
    if match:
        return float(match.group(1).replace(',', ''))
    return 0

df['elevation_numeric'] = df[elevation_col].apply(clean_elevation)


df_all = df.sort_values(by='elevation_numeric', ascending=True)


plt.figure(figsize=(12, 45))
sns.set_theme(style="whitegrid")


ax = sns.barplot(
    data=df_all,
    x='elevation_numeric',
    y=country_col,
    palette="viridis"
)


for i, v in enumerate(df_all['elevation_numeric']):
    ax.text(v + 5, i, f"{int(v)}m", va='center', fontsize=8)

plt.title('Tüm Ülkelerin Ortalama Yükseltileri (Sıralı Tam Liste)', fontsize=16)
plt.xlabel('Ortalama Yükselti (Metre)', fontsize=12)
plt.ylabel('Ülke', fontsize=10)


plt.tight_layout()
plt.show()
# Out:
# Using Colab cache for faster access to the 'list-of-countries-by-average-elevation' dataset.
# /tmp/ipykernel_1479/2130495607.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
import os


df_global = temiz_veriler['GlobalTemperatures.csv'].copy()
df_global['dt'] = pd.to_datetime(df_global['dt'])
df_global['year'] = df_global['dt'].dt.year
yearly_temp = df_global.groupby('year')['LandAverageTemperature'].mean()


path = kagglehub.dataset_download("jarredpriester/global-sea-level-rise")
csv_path = os.path.join(path, 'Global_sea_level_rise.csv')
df_sea = pd.read_csv(csv_path)
df_sea['date'] = pd.to_datetime(df_sea['date'])

df_sea['year'] = df_sea['date'].dt.year
yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()



fig, ax1 = plt.subplots(figsize=(14, 8))
sns.set_style("whitegrid")


color_temp = 'tab:red'
ax1.set_xlabel('Yıl', fontsize=12)
ax1.set_ylabel('Küresel Kara Sıcaklığı (°C)', color=color_temp, fontsize=12)
ax1.plot(yearly_temp.index, yearly_temp.values, color=color_temp, alpha=0.3, label='Yıllık Ort. Sıcaklık')
ax1.plot(yearly_temp.index, yearly_temp.rolling(window=10).mean(), color='darkred', linewidth=3, label='Sıcaklık Trendi (10 Yıl)')
ax1.tick_params(axis='y', labelcolor=color_temp)


ax2 = ax1.twinx()
color_sea = '#2c7bb6'
ax2.set_ylabel('Deniz Seviyesi Değişimi (mm)', color=color_sea, fontsize=12)
ax2.plot(yearly_sea.index, yearly_sea.values, color=color_sea, linewidth=2.5, label='Deniz Seviyesi Artışı')
ax2.tick_params(axis='y', labelcolor=color_sea)


plt.title('Küresel Isınma vs. Deniz Seviyesi Artışı (1880 - 2015)', fontsize=16, fontweight='bold', pad=20)


lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')


plt.xlim(1880, 2015)

plt.tight_layout()
plt.show()
# Out:
# Using Colab cache for faster access to the 'global-sea-level-rise' dataset.

# %%
import pandas as pd


df_correlation = pd.merge(
    yearly_temp.to_frame(name='Temperature'),
    yearly_sea.to_frame(name='SeaLevel'),
    left_index=True,
    right_index=True
)


correlation_value = df_correlation['Temperature'].corr(df_correlation['SeaLevel'])

print(f"--- Analiz Sonucu ---")
print(f"Sıcaklık ve Deniz Seviyesi arasındaki Korelasyon Katsayısı: {correlation_value:.4f}")


import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.regplot(data=df_correlation, x='Temperature', y='SeaLevel',
            scatter_kws={'alpha':0.5, 'color':'gray'},
            line_kws={'color':'red', 'label':f'Korelasyon: {correlation_value:.4f}'})

plt.title('Sıcaklık Artışı vs Deniz Seviyesi Yükselmesi İlişkisi', fontsize=14)
plt.xlabel('Küresel Kara Sıcaklığı (°C)')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- Analiz Sonucu ---
# Sıcaklık ve Deniz Seviyesi arasındaki Korelasyon Katsayısı: 0.8964

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# polinom regresyon özellikleri. 2. dereceden
poly_features = PolynomialFeatures(degree=2)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%80)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%20)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 9.71 °C

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# Veriyi hazırlama
df_xgb = yearly_temp.to_frame(name='temp')
df_xgb['year'] = df_xgb.index
df_xgb['diff'] = df_xgb['temp'].diff() # Yıllık artış miktarı

for i in range(1, 4):
    df_xgb[f'lag_{i}'] = df_xgb['diff'].shift(i)

df_xgb = df_xgb.dropna()

# Train Test ayrımı.
X = df_xgb.drop(columns=['temp', 'diff', 'year'])
y = df_xgb['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# XGBoost modelini eğitme
model_xgb = xgb.XGBRegressor(n_estimators=100, learning_rate=0.05, max_depth=5)
model_xgb.fit(X_train, y_train)

# Hata hesaplama RMSE
y_pred_test = model_xgb.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

# Gelecek tahmini
future_years = np.arange(df_xgb['year'].max() + 1, 2101)
last_temp = df_xgb['temp'].iloc[-1]
current_lags = df_xgb.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
temp_acc = last_temp

for yr in future_years:
    pred_diff = model_xgb.predict(current_lags.reshape(1, -1))[0]
    temp_acc += pred_diff
    future_preds.append(temp_acc)
    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(df_xgb['year'], df_xgb['temp'], color='#2c3e50', label='Gerçek Veri', alpha=0.7)

plt.plot(future_years, future_preds, color='#d35400', linewidth=3, linestyle='--', label='XGBoost 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f}', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d35400'))

plt.title('XGBoost ile Küresel Sıcaklık Değişimi ve 2100 Projeksiyonu', fontsize=16)
plt.ylabel('Sıcaklık (°C)')
plt.legend()
plt.show()

print(f"XGBoost 2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# XGBoost 2100 Yılı Tahmini: 12.47 °C

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# Veri hazırlama
df_rf = yearly_temp.to_frame(name='temp')
df_rf['year'] = df_rf.index
df_rf['diff'] = df_rf['temp'].diff()

for i in range(1, 4):
    df_rf[f'lag_{i}'] = df_rf['diff'].shift(i)

df_rf = df_rf.dropna()

# Train-Test ayrımı
X = df_rf.drop(columns=['temp', 'diff', 'year'])
y = df_rf['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 500 ağaç kullanarak random forest modeli kurma.
rf_model = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)
rf_model.fit(X_train.values, y_train)

# Hata hesaplama RMSE
y_pred_test = rf_model.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

# Gelecek Tahmini.
future_years = np.arange(df_rf['year'].max() + 1, 2101)
last_temp = df_rf['temp'].iloc[-1]
current_lags = df_rf.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
temp_acc = last_temp

for yr in future_years:
    pred_diff = rf_model.predict(current_lags.reshape(1, -1))[0]
    temp_acc += pred_diff
    future_preds.append(temp_acc)
    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(df_rf['year'], df_rf['temp'], color='#2980b9', label='Gerçek Veri (Geçmiş)', alpha=0.7)

plt.plot(future_years, future_preds, color='#27ae60', linewidth=3, linestyle='--', label='Random Forest 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f}', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#27ae60'))

plt.title('Random Forest ile Küresel Sıcaklık Analizi (2100)', fontsize=16)
plt.ylabel('Sıcaklık (°C)')
plt.legend()
plt.show()

print(f"Random Forest 2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# Random Forest 2100 Yılı Tahmini: 12.30 °C

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=2)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%80)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%20)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 255.39 mm

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Veri Hazırlama
full_path = os.path.join(path, 'Global_sea_level_rise.csv')
df_sea = pd.read_csv(full_path)
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year
yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean().to_frame(name='level')

df_xgb = yearly_sea.copy()
df_xgb['diff'] = df_xgb['level'].diff()

for i in range(1, 4):
    df_xgb[f'lag_{i}'] = df_xgb['diff'].shift(i)

df_xgb = df_xgb.dropna()

# Train-Test ayrımı
X = df_xgb.drop(columns=['level', 'diff'])
y = df_xgb['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# XGBoost modelini eğitme
model_xgb = xgb.XGBRegressor(n_estimators=150, learning_rate=0.05, max_depth=4)
model_xgb.fit(X_train, y_train)

# Gelecek Tahmini
future_years = np.arange(df_xgb.index.max() + 1, 2101)
last_real_level = df_xgb['level'].iloc[-1]
current_lags = df_xgb.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
level_accumulator = last_real_level

for yr in future_years:
    pred_diff = model_xgb.predict(current_lags.reshape(1, -1))[0]
    level_accumulator += pred_diff
    future_preds.append(level_accumulator)

    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(yearly_sea.index, yearly_sea['level'], color='#2c3e50', label='Gerçek Veri', alpha=0.7)

plt.plot(future_years, future_preds, color='#e67e22', linewidth=3, linestyle='--', label='XGBoost 2100 Tahmini')

test_preds_diff = model_xgb.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds_diff))

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#e67e22'))

plt.title('XGBoost ile Deniz Seviyesi Artış Projeksiyonu (2100)', fontsize=16)
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"XGBoost 2100 Yılı Tahmini: {future_preds[-1]:.2f} mm")
# Out:
# XGBoost 2100 Yılı Tahmini: 127.88 mm

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Veriyi hazırlama
full_path = os.path.join(path, 'Global_sea_level_rise.csv')
df_sea = pd.read_csv(full_path)
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year
yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean().to_frame(name='level')

df_rf = yearly_sea.copy()
df_rf['diff'] = df_rf['level'].diff()

for i in range(1, 4):
    df_rf[f'lag_{i}'] = df_rf['diff'].shift(i)

df_rf = df_rf.dropna()

# Train-Test ayrımı
X = df_rf.drop(columns=['level', 'diff'])
y = df_rf['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Random forest model eğitimi
rf_model_sea = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)
rf_model_sea.fit(X_train.values, y_train)

# Geleceği Tahmin Etme
future_years = np.arange(df_rf.index.max() + 1, 2101)
last_real_level = df_rf['level'].iloc[-1]
current_lags = df_rf.iloc[-1][['diff', 'lag_1', 'lag_2']].values

rf_predictions = []
level_acc = last_real_level

for yr in future_years:
    pred_diff = rf_model_sea.predict(current_lags.reshape(1, -1))[0]
    level_acc += pred_diff
    rf_predictions.append(level_acc)

    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Hata hesaplama RMSE
test_preds_diff = rf_model_sea.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds_diff))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(yearly_sea.index, yearly_sea['level'], color='#34495e', label='Gerçek Veri', alpha=0.7)
plt.plot(future_years, rf_predictions, color='#27ae60', linewidth=3, linestyle='--', label='Random Forest 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#27ae60'))

plt.title('Random Forest ile Deniz Seviyesi Artış Analizi (2100)', fontsize=16)
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"Random Forest 2100 Yılı Tahmini: {rf_predictions[-1]:.2f} mm")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# Random Forest 2100 Yılı Tahmini: 165.12 mm

# %%
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS
REARRAGEMENT: EXPERIMENTS ON HYPERPARAMETERS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%5
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# polinom regresyon özellikleri. 2. dereceden
poly_features = PolynomialFeatures(degree=2)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 10.36 °C

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%10
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# polinom regresyon özellikleri. 2. dereceden
poly_features = PolynomialFeatures(degree=2)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 11.00 °C

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# polinom regresyon özellikleri. 3. dereceden
poly_features = PolynomialFeatures(degree=3)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%80)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%20)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 4.41 °C

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# polinom regresyon özellikleri. 3. dereceden
poly_features = PolynomialFeatures(degree=3)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%90)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%10)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 10.80 °C

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# polinom regresyon özellikleri. 3. dereceden
poly_features = PolynomialFeatures(degree=3)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 13.39 °C

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# polinom regresyon özellikleri. 4. dereceden
poly_features = PolynomialFeatures(degree=4)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 13.60 °C

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Veriyi hazırlama
X = yearly_temp.index.values.reshape(-1, 1)
y = yearly_temp.values

# Train-test ayrımı test=%20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# polinom regresyon özellikleri. 5. dereceden
poly_features = PolynomialFeatures(degree=5)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Eğitim
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Gelecek Tahmini
future_years = np.arange(1850, 2101).reshape(-1, 1)
future_years_poly = poly_features.transform(future_years)
future_preds = model.predict(future_years_poly)

# Rmse hesabı
y_test_pred = model.predict(X_test_poly)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.scatter(X_train, y_train, color='blue', alpha=0.3, s=20, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='darkblue', alpha=0.6, s=25, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='red', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {test_rmse:.4f} °C', transform=plt.gca().transAxes,
         fontsize=13, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))

plt.axvline(x=X_test[0], color='black', linestyle='--', alpha=0.3) # Split çizgisi
plt.text(X_test[0], plt.ylim()[0]+0.1, ' Test Ayrımı', fontsize=10)

plt.title('Polinom Regresyon ile Küresel Sıcaklık Projeksiyonu (2100)', fontsize=16, fontweight='bold')
plt.xlabel('Yıl')
plt.ylabel('Sıcaklık (°C)')
plt.legend(loc='lower right')
plt.show()

print(f"2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# 2100 Yılı Tahmini: 13.82 °C

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# Veriyi hazırlama
df_xgb = yearly_temp.to_frame(name='temp')
df_xgb['year'] = df_xgb.index
df_xgb['diff'] = df_xgb['temp'].diff() # Yıllık artış miktarı

for i in range(1, 4):
    df_xgb[f'lag_{i}'] = df_xgb['diff'].shift(i)

df_xgb = df_xgb.dropna()

# Train Test ayrımı.
X = df_xgb.drop(columns=['temp', 'diff', 'year'])
y = df_xgb['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# XGBoost modelini eğitme
model_xgb = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5)
model_xgb.fit(X_train, y_train)

# Hata hesaplama RMSE
y_pred_test = model_xgb.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

# Gelecek tahmini
future_years = np.arange(df_xgb['year'].max() + 1, 2101)
last_temp = df_xgb['temp'].iloc[-1]
current_lags = df_xgb.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
temp_acc = last_temp

for yr in future_years:
    pred_diff = model_xgb.predict(current_lags.reshape(1, -1))[0]
    temp_acc += pred_diff
    future_preds.append(temp_acc)
    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(df_xgb['year'], df_xgb['temp'], color='#2c3e50', label='Gerçek Veri', alpha=0.7)

plt.plot(future_years, future_preds, color='#d35400', linewidth=3, linestyle='--', label='XGBoost 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f}', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d35400'))

plt.title('XGBoost ile Küresel Sıcaklık Değişimi ve 2100 Projeksiyonu', fontsize=16)
plt.ylabel('Sıcaklık (°C)')
plt.legend()
plt.show()

print(f"XGBoost 2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# XGBoost 2100 Yılı Tahmini: 10.79 °C

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# Veriyi hazırlama
df_xgb = yearly_temp.to_frame(name='temp')
df_xgb['year'] = df_xgb.index
df_xgb['diff'] = df_xgb['temp'].diff() # Yıllık artış miktarı

for i in range(1, 4):
    df_xgb[f'lag_{i}'] = df_xgb['diff'].shift(i)

df_xgb = df_xgb.dropna()

# Train Test ayrımı.
X = df_xgb.drop(columns=['temp', 'diff', 'year'])
y = df_xgb['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# XGBoost modelini eğitme
model_xgb = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5)
model_xgb.fit(X_train, y_train)

# Hata hesaplama RMSE
y_pred_test = model_xgb.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

# Gelecek tahmini
future_years = np.arange(df_xgb['year'].max() + 1, 2101)
last_temp = df_xgb['temp'].iloc[-1]
current_lags = df_xgb.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
temp_acc = last_temp

for yr in future_years:
    pred_diff = model_xgb.predict(current_lags.reshape(1, -1))[0]
    temp_acc += pred_diff
    future_preds.append(temp_acc)
    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(df_xgb['year'], df_xgb['temp'], color='#2c3e50', label='Gerçek Veri', alpha=0.7)

plt.plot(future_years, future_preds, color='#d35400', linewidth=3, linestyle='--', label='XGBoost 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f}', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d35400'))

plt.title('XGBoost ile Küresel Sıcaklık Değişimi ve 2100 Projeksiyonu', fontsize=16)
plt.ylabel('Sıcaklık (°C)')
plt.legend()
plt.show()

print(f"XGBoost 2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# XGBoost 2100 Yılı Tahmini: 11.52 °C

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# Veri hazırlama
df_rf = yearly_temp.to_frame(name='temp')
df_rf['year'] = df_rf.index
df_rf['diff'] = df_rf['temp'].diff()

for i in range(1, 4):
    df_rf[f'lag_{i}'] = df_rf['diff'].shift(i)

df_rf = df_rf.dropna()

# Train-Test ayrımı
X = df_rf.drop(columns=['temp', 'diff', 'year'])
y = df_rf['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# 500 ağaç kullanarak random forest modeli kurma.
rf_model = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)
rf_model.fit(X_train.values, y_train)

# Hata hesaplama RMSE
y_pred_test = rf_model.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

# Gelecek Tahmini.
future_years = np.arange(df_rf['year'].max() + 1, 2101)
last_temp = df_rf['temp'].iloc[-1]
current_lags = df_rf.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
temp_acc = last_temp

for yr in future_years:
    pred_diff = rf_model.predict(current_lags.reshape(1, -1))[0]
    temp_acc += pred_diff
    future_preds.append(temp_acc)
    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(df_rf['year'], df_rf['temp'], color='#2980b9', label='Gerçek Veri (Geçmiş)', alpha=0.7)

plt.plot(future_years, future_preds, color='#27ae60', linewidth=3, linestyle='--', label='Random Forest 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f}', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#27ae60'))

plt.title('Random Forest ile Küresel Sıcaklık Analizi (2100)', fontsize=16)
plt.ylabel('Sıcaklık (°C)')
plt.legend()
plt.show()

print(f"Random Forest 2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# Random Forest 2100 Yılı Tahmini: 13.15 °C

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# Veri hazırlama
df_rf = yearly_temp.to_frame(name='temp')
df_rf['year'] = df_rf.index
df_rf['diff'] = df_rf['temp'].diff()

for i in range(1, 4):
    df_rf[f'lag_{i}'] = df_rf['diff'].shift(i)

df_rf = df_rf.dropna()

# Train-Test ayrımı
X = df_rf.drop(columns=['temp', 'diff', 'year'])
y = df_rf['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# 500 ağaç kullanarak random forest modeli kurma.
rf_model = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)
rf_model.fit(X_train.values, y_train)

# Hata hesaplama RMSE
y_pred_test = rf_model.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

# Gelecek Tahmini.
future_years = np.arange(df_rf['year'].max() + 1, 2101)
last_temp = df_rf['temp'].iloc[-1]
current_lags = df_rf.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
temp_acc = last_temp

for yr in future_years:
    pred_diff = rf_model.predict(current_lags.reshape(1, -1))[0]
    temp_acc += pred_diff
    future_preds.append(temp_acc)
    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(df_rf['year'], df_rf['temp'], color='#2980b9', label='Gerçek Veri (Geçmiş)', alpha=0.7)

plt.plot(future_years, future_preds, color='#27ae60', linewidth=3, linestyle='--', label='Random Forest 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f}', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#27ae60'))

plt.title('Random Forest ile Küresel Sıcaklık Analizi (2100)', fontsize=16)
plt.ylabel('Sıcaklık (°C)')
plt.legend()
plt.show()

print(f"Random Forest 2100 Yılı Tahmini: {future_preds[-1]:.2f} °C")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# Random Forest 2100 Yılı Tahmini: 12.82 °C

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=2)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%90)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%10)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 265.10 mm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=2)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 296.25 mm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=3)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%80)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%20)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 230.22 mm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=3)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%90)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%10)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 296.53 mm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=3)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 423.84 mm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=4)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 431.32 mm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dosyayı yüklüyoruz.
csv_name = 'Global_sea_level_rise.csv'
full_path = os.path.join(path, csv_name)
df_sea = pd.read_csv(full_path)

# Veri ön işleme
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year

yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean()

X = yearly_sea.index.values.reshape(-1, 1)
y = yearly_sea.values

# Train Test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# Polinom Regresyon
poly_feat = PolynomialFeatures(degree=5)
X_train_poly = poly_feat.fit_transform(X_train)
X_test_poly = poly_feat.transform(X_test)

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

# Gelecek tahmini
future_years = np.arange(X.min(), 2101).reshape(-1, 1)
future_preds = poly_model.predict(poly_feat.transform(future_years))

# Hata hesabı RMSE
y_test_pred = poly_model.predict(X_test_poly)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_theme(style="whitegrid")

plt.scatter(X_train, y_train, color='#2c7bb6', alpha=0.3, label='Eğitim Verisi (%95)')
plt.scatter(X_test, y_test, color='#004488', alpha=0.6, label='Test Verisi (%5)')

plt.plot(future_years, future_preds, color='#d7191c', linewidth=3, label='Polinom Trend (2100 Projeksiyonu)')

plt.text(0.05, 0.9, f'Test RMSE: {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#d7191c'))

plt.axvline(x=X_test[0], color='gray', linestyle='--', alpha=0.5)
plt.title('Deniz Seviyesi Hızlanan Artış Projeksiyonu (1880 - 2100)', fontsize=16)
plt.xlabel('Yıl')
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"2100 Yılı Tahmini Toplam Yükseliş: {future_preds[-1]:.2f} mm")
# Out:
# 2100 Yılı Tahmini Toplam Yükseliş: 438.90 mm

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Veri Hazırlama
full_path = os.path.join(path, 'Global_sea_level_rise.csv')
df_sea = pd.read_csv(full_path)
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year
yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean().to_frame(name='level')

df_xgb = yearly_sea.copy()
df_xgb['diff'] = df_xgb['level'].diff()

for i in range(1, 4):
    df_xgb[f'lag_{i}'] = df_xgb['diff'].shift(i)

df_xgb = df_xgb.dropna()

# Train-Test ayrımı
X = df_xgb.drop(columns=['level', 'diff'])
y = df_xgb['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# XGBoost modelini eğitme
model_xgb = xgb.XGBRegressor(n_estimators=150, learning_rate=0.05, max_depth=4)
model_xgb.fit(X_train, y_train)

# Gelecek Tahmini
future_years = np.arange(df_xgb.index.max() + 1, 2101)
last_real_level = df_xgb['level'].iloc[-1]
current_lags = df_xgb.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
level_accumulator = last_real_level

for yr in future_years:
    pred_diff = model_xgb.predict(current_lags.reshape(1, -1))[0]
    level_accumulator += pred_diff
    future_preds.append(level_accumulator)

    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(yearly_sea.index, yearly_sea['level'], color='#2c3e50', label='Gerçek Veri', alpha=0.7)

plt.plot(future_years, future_preds, color='#e67e22', linewidth=3, linestyle='--', label='XGBoost 2100 Tahmini')

test_preds_diff = model_xgb.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds_diff))

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#e67e22'))

plt.title('XGBoost ile Deniz Seviyesi Artış Projeksiyonu (2100)', fontsize=16)
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"XGBoost 2100 Yılı Tahmini: {future_preds[-1]:.2f} mm")
# Out:
# XGBoost 2100 Yılı Tahmini: 237.85 mm

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Veri Hazırlama
full_path = os.path.join(path, 'Global_sea_level_rise.csv')
df_sea = pd.read_csv(full_path)
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year
yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean().to_frame(name='level')

df_xgb = yearly_sea.copy()
df_xgb['diff'] = df_xgb['level'].diff()

for i in range(1, 4):
    df_xgb[f'lag_{i}'] = df_xgb['diff'].shift(i)

df_xgb = df_xgb.dropna()

# Train-Test ayrımı
X = df_xgb.drop(columns=['level', 'diff'])
y = df_xgb['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# XGBoost modelini eğitme
model_xgb = xgb.XGBRegressor(n_estimators=150, learning_rate=0.05, max_depth=4)
model_xgb.fit(X_train, y_train)

# Gelecek Tahmini
future_years = np.arange(df_xgb.index.max() + 1, 2101)
last_real_level = df_xgb['level'].iloc[-1]
current_lags = df_xgb.iloc[-1][['diff', 'lag_1', 'lag_2']].values

future_preds = []
level_accumulator = last_real_level

for yr in future_years:
    pred_diff = model_xgb.predict(current_lags.reshape(1, -1))[0]
    level_accumulator += pred_diff
    future_preds.append(level_accumulator)

    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(yearly_sea.index, yearly_sea['level'], color='#2c3e50', label='Gerçek Veri', alpha=0.7)

plt.plot(future_years, future_preds, color='#e67e22', linewidth=3, linestyle='--', label='XGBoost 2100 Tahmini')

test_preds_diff = model_xgb.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds_diff))

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#e67e22'))

plt.title('XGBoost ile Deniz Seviyesi Artış Projeksiyonu (2100)', fontsize=16)
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"XGBoost 2100 Yılı Tahmini: {future_preds[-1]:.2f} mm")
# Out:
# XGBoost 2100 Yılı Tahmini: 258.13 mm

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Veriyi hazırlama
full_path = os.path.join(path, 'Global_sea_level_rise.csv')
df_sea = pd.read_csv(full_path)
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year
yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean().to_frame(name='level')

df_rf = yearly_sea.copy()
df_rf['diff'] = df_rf['level'].diff()

for i in range(1, 4):
    df_rf[f'lag_{i}'] = df_rf['diff'].shift(i)

df_rf = df_rf.dropna()

# Train-Test ayrımı
X = df_rf.drop(columns=['level', 'diff'])
y = df_rf['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# Random forest model eğitimi
rf_model_sea = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)
rf_model_sea.fit(X_train.values, y_train)

# Geleceği Tahmin Etme
future_years = np.arange(df_rf.index.max() + 1, 2101)
last_real_level = df_rf['level'].iloc[-1]
current_lags = df_rf.iloc[-1][['diff', 'lag_1', 'lag_2']].values

rf_predictions = []
level_acc = last_real_level

for yr in future_years:
    pred_diff = rf_model_sea.predict(current_lags.reshape(1, -1))[0]
    level_acc += pred_diff
    rf_predictions.append(level_acc)

    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Hata hesaplama RMSE
test_preds_diff = rf_model_sea.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds_diff))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(yearly_sea.index, yearly_sea['level'], color='#34495e', label='Gerçek Veri', alpha=0.7)
plt.plot(future_years, rf_predictions, color='#27ae60', linewidth=3, linestyle='--', label='Random Forest 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#27ae60'))

plt.title('Random Forest ile Deniz Seviyesi Artış Analizi (2100)', fontsize=16)
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"Random Forest 2100 Yılı Tahmini: {rf_predictions[-1]:.2f} mm")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# Random Forest 2100 Yılı Tahmini: 222.24 mm

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Veriyi hazırlama
full_path = os.path.join(path, 'Global_sea_level_rise.csv')
df_sea = pd.read_csv(full_path)
df_sea['date'] = pd.to_datetime(df_sea['date'])
df_sea['year'] = df_sea['date'].dt.year
yearly_sea = df_sea.groupby('year')['mmfrom1993-2008average'].mean().to_frame(name='level')

df_rf = yearly_sea.copy()
df_rf['diff'] = df_rf['level'].diff()

for i in range(1, 4):
    df_rf[f'lag_{i}'] = df_rf['diff'].shift(i)

df_rf = df_rf.dropna()

# Train-Test ayrımı
X = df_rf.drop(columns=['level', 'diff'])
y = df_rf['diff']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# Random forest model eğitimi
rf_model_sea = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)
rf_model_sea.fit(X_train.values, y_train)

# Geleceği Tahmin Etme
future_years = np.arange(df_rf.index.max() + 1, 2101)
last_real_level = df_rf['level'].iloc[-1]
current_lags = df_rf.iloc[-1][['diff', 'lag_1', 'lag_2']].values

rf_predictions = []
level_acc = last_real_level

for yr in future_years:
    pred_diff = rf_model_sea.predict(current_lags.reshape(1, -1))[0]
    level_acc += pred_diff
    rf_predictions.append(level_acc)

    current_lags = np.array([pred_diff, current_lags[0], current_lags[1]])

# Hata hesaplama RMSE
test_preds_diff = rf_model_sea.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds_diff))

# Görselleştirme
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

plt.plot(yearly_sea.index, yearly_sea['level'], color='#34495e', label='Gerçek Veri', alpha=0.7)
plt.plot(future_years, rf_predictions, color='#27ae60', linewidth=3, linestyle='--', label='Random Forest 2100 Tahmini')

plt.text(0.05, 0.9, f'Test RMSE (Değişim): {rmse_test:.4f} mm', transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', bbox=dict(facecolor='white', alpha=0.8, edgecolor='#27ae60'))

plt.title('Random Forest ile Deniz Seviyesi Artış Analizi (2100)', fontsize=16)
plt.ylabel('Deniz Seviyesi Değişimi (mm)')
plt.legend()
plt.show()

print(f"Random Forest 2100 Yılı Tahmini: {rf_predictions[-1]:.2f} mm")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# Random Forest 2100 Yılı Tahmini: 228.60 mm
